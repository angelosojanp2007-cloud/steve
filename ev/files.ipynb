# %%
f = open("file.txt","rt")
print(f.readline())
f.readline()
print(f.readline())
f.close()
# Out:
# hello world 1
#
# hello world 3

# %%
f = open("write.txt","at")
f.write(" This is a appended file")
f.close()
f = open("write.txt","rt")
print(f.read())
f.close()
# Out:
# This is a overwrite file This is a appended file

# %%
import os
os.remove("write.txt")
